# %% [markdown]
# # Sample Data Creation Script

# %% [markdown]
# ## Descriptions

# %% [markdown]
# ![Data Sampling Requirements](./figs/data_sampling_requirements.png)
# ![Data Sampling Flow](./figs/data_sampling_flow.png)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

from k_anonymization import datasets

# %% [markdown]
# ## Data Creation

# %% [markdown]
# ### Original Data

# %%
DATASET = datasets.ADULT
org_df = DATASET.df
org_df.shape[0]
# Out:
# 30162

# %% [markdown]
# ### Unique-QIDs Data

# %%
freq_org_df = org_df.groupby(DATASET.qids, as_index=False).count()
org_unique_indices = freq_org_df[freq_org_df[DATASET.target] == 1].index

# %%
org_unique_df = pd.merge(
    org_df.reset_index(),
    freq_org_df[freq_org_df[DATASET.target] == 1][DATASET.qids],
    on=DATASET.qids,
    how="right",
)
org_unique_df
# Out:
#        index     sex  age                race      marital-status  \
# 0       3307  Female   17  Amer-Indian-Eskimo       Never-married
# 1      13628  Female   17  Amer-Indian-Eskimo       Never-married
# 2       1357  Female   17  Asian-Pac-Islander       Never-married
# 3      18068  Female   17               Black       Never-married
# 4      24901  Female   17               Black       Never-married
# ...      ...     ...  ...                 ...                 ...
# 14016   9435    Male   90               White  Married-civ-spouse
# 14017   3734    Male   90               White       Never-married
# 14018  11093    Male   90               White       Never-married
# 14019  22283    Male   90               White       Never-married
# 14020  14226    Male   90               White             Widowed
#
#           education native-country         workclass         occupation  \
# 0              10th  United-States           Private      Other-service
# 1              11th  United-States           Private      Other-service
# 2              11th  United-States           Private       Adm-clerical
# 3              10th  United-States           Private      Other-service
# 4              11th  United-States       Federal-gov       Adm-clerical
# ...             ...            ...               ...                ...
# 14016  Some-college  United-States  Self-emp-not-inc    Farming-fishing
# 14017          11th  United-States           Private  Handlers-cleaners
# 14018     Bachelors  United-States           Private    Exec-managerial
# 14019       HS-grad  United-States  Self-emp-not-inc    Exec-managerial
# 14020       HS-grad  United-States           Private   Transport-moving
#
#       salary-class
# 0            <=50K
# 1            <=50K
# 2            <=50K
# 3            <=50K
# 4            <=50K
# ...            ...
# 14016        <=50K
# 14017        <=50K
# 14018        <=50K
# 14019        <=50K
# 14020        <=50K
#
# [14021 rows x 10 columns]

# %% [markdown]
# #### Unique-QIDs Data, Target = "$\tiny\leq$50K"

# %%
org_unique_df_A = org_unique_df[
    org_unique_df[DATASET.target] == org_unique_df.loc[0, DATASET.target]
]
org_unique_df_A
# Out:
#        index     sex  age                race      marital-status  \
# 0       3307  Female   17  Amer-Indian-Eskimo       Never-married
# 1      13628  Female   17  Amer-Indian-Eskimo       Never-married
# 2       1357  Female   17  Asian-Pac-Islander       Never-married
# 3      18068  Female   17               Black       Never-married
# 4      24901  Female   17               Black       Never-married
# ...      ...     ...  ...                 ...                 ...
# 14016   9435    Male   90               White  Married-civ-spouse
# 14017   3734    Male   90               White       Never-married
# 14018  11093    Male   90               White       Never-married
# 14019  22283    Male   90               White       Never-married
# 14020  14226    Male   90               White             Widowed
#
#           education native-country         workclass         occupation  \
# 0              10th  United-States           Private      Other-service
# 1              11th  United-States           Private      Other-service
# 2              11th  United-States           Private       Adm-clerical
# 3              10th  United-States           Private      Other-service
# 4              11th  United-States       Federal-gov       Adm-clerical
# ...             ...            ...               ...                ...
# 14016  Some-college  United-States  Self-emp-not-inc    Farming-fishing
# 14017          11th  United-States           Private  Handlers-cleaners
# 14018     Bachelors  United-States           Private    Exec-managerial
# 14019       HS-grad  United-States  Self-emp-not-inc    Exec-managerial
# 14020       HS-grad  United-States           Private   Transport-moving
#
#       salary-class
# 0            <=50K
# 1            <=50K
# 2            <=50K
# 3            <=50K
# 4            <=50K
# ...            ...
# 14016        <=50K
# 14017        <=50K
# 14018        <=50K
# 14019        <=50K
# 14020        <=50K
#
# [11016 rows x 10 columns]

# %% [markdown]
# #### Unique-QIDs Data, Target = ">50K"

# %%
org_unique_df_B = org_unique_df[
    org_unique_df[DATASET.target] != org_unique_df.loc[0, DATASET.target]
]
org_unique_df_B
# Out:
#        index     sex  age                race      marital-status  \
# 211     5158  Female   21  Amer-Indian-Eskimo  Married-civ-spouse
# 229    10132  Female   21               Black       Never-married
# 278    22597  Female   22  Amer-Indian-Eskimo       Never-married
# 313    27697  Female   22               White   Married-AF-spouse
# 342     1678  Female   22               White       Never-married
# ...      ...     ...  ...                 ...                 ...
# 14003   4953    Male   90               Black       Never-married
# 14009   8287    Male   90               White  Married-civ-spouse
# 14011   9749    Male   90               White  Married-civ-spouse
# 14014   4921    Male   90               White  Married-civ-spouse
# 14015   8132    Male   90               White  Married-civ-spouse
#
#           education      native-country         workclass       occupation  \
# 211      Assoc-acdm       United-States           Private     Adm-clerical
# 229    Some-college       United-States           Private  Protective-serv
# 278       Bachelors       United-States           Private   Prof-specialty
# 313    Some-college       United-States           Private    Other-service
# 342         HS-grad  Dominican-Republic  Self-emp-not-inc   Prof-specialty
# ...             ...                 ...               ...              ...
# 14003       Masters       United-States           Private  Exec-managerial
# 14009     Bachelors       United-States           Private            Sales
# 14011       HS-grad             Ecuador           Private     Craft-repair
# 14014       Masters       United-States         Local-gov  Exec-managerial
# 14015   Prof-school       United-States           Private   Prof-specialty
#
#       salary-class
# 211           >50K
# 229           >50K
# 278           >50K
# 313           >50K
# 342           >50K
# ...            ...
# 14003         >50K
# 14009         >50K
# 14011         >50K
# 14014         >50K
# 14015         >50K
#
# [3005 rows x 10 columns]

# %% [markdown]
# ### * Sample Data

# %% [markdown]
# Use a seed for reproducibility

# %%
SEED = 202512

# %%
sample_A = org_unique_df_A.sample(n=1500, random_state=SEED)
sample_B = org_unique_df_B.sample(n=1500, random_state=SEED)
sample = pd.concat([sample_A, sample_B], axis=0).sample(frac=1, random_state=SEED)
sample
# Out:
#        index     sex  age                race      marital-status  \
# 13418  17207    Male   64  Asian-Pac-Islander  Married-civ-spouse
# 7477    2307    Male   31  Asian-Pac-Islander  Married-civ-spouse
# 11558  11823    Male   50  Asian-Pac-Islander  Married-civ-spouse
# 9353    6647    Male   39               White            Divorced
# 4915    8704  Female   62               White  Married-civ-spouse
# ...      ...     ...  ...                 ...                 ...
# 3205   19401  Female   44               Black           Separated
# 9329   21123    Male   39               Black  Married-civ-spouse
# 896     4005  Female   27               White  Married-civ-spouse
# 2469    8468  Female   38               White             Widowed
# 3678    1646  Female   47               White       Never-married
#
#           education native-country    workclass        occupation salary-class
# 13418    Assoc-acdm  United-States  Federal-gov     Other-service         >50K
# 7477     Assoc-acdm  United-States      Private      Craft-repair         >50K
# 11558       HS-grad          South      Private    Prof-specialty         >50K
# 9353      Bachelors         Mexico    State-gov   Protective-serv         >50K
# 4915      Bachelors  United-States      Private      Adm-clerical         >50K
# ...             ...            ...          ...               ...          ...
# 3205   Some-college  United-States      Private    Prof-specialty        <=50K
# 9329        HS-grad  United-States      Private  Transport-moving         >50K
# 896    Some-college  United-States      Private   Exec-managerial         >50K
# 2469   Some-college  United-States      Private   Exec-managerial         >50K
# 3678            9th  United-States      Private     Other-service        <=50K
#
# [3000 rows x 10 columns]

# %% [markdown]
# ### * Validation Data

# %%
unsampled_A = org_unique_df_A[~org_unique_df_A.index.isin(sample_A.index)]
unsampled_B = org_unique_df_B[~org_unique_df_B.index.isin(sample_B.index)]

# %%
predict_org_A = unsampled_A.sample(n=300, random_state=SEED)
predict_org_B = unsampled_B.sample(n=300, random_state=SEED)
predict_org = pd.concat([predict_org_A, predict_org_B], axis=0).sample(
    frac=1, random_state=SEED
)
predict_org
# Out:
#        index     sex  age   race      marital-status     education  \
# 5292   13519  Female   80  White             Widowed  Some-college
# 13659  28902    Male   67  White  Married-civ-spouse  Some-college
# 5652   15774    Male   21  White       Never-married           9th
# 10839  14679    Male   46  Black  Married-civ-spouse       Masters
# 9664   11672    Male   40  White       Never-married       1st-4th
# ...      ...     ...  ...    ...                 ...           ...
# 2935    4930  Female   42  Black  Married-civ-spouse     Bachelors
# 3097    9939  Female   43  White            Divorced       HS-grad
# 3090   13175  Female   43  White            Divorced     Bachelors
# 2427     924  Female   38  White  Married-civ-spouse       HS-grad
# 1609   18663  Female   32  White       Never-married     Bachelors
#
#       native-country  workclass        occupation salary-class
# 5292   United-States    Private      Adm-clerical        <=50K
# 13659  United-States  State-gov   Protective-serv         >50K
# 5652   United-States    Private  Transport-moving        <=50K
# 10839  United-States  Local-gov    Prof-specialty         >50K
# 9664     El-Salvador    Private     Other-service        <=50K
# ...              ...        ...               ...          ...
# 2935   United-States    Private   Exec-managerial         >50K
# 3097   United-States  State-gov      Adm-clerical         >50K
# 3090   United-States    Private    Prof-specialty         >50K
# 2427   United-States  State-gov    Prof-specialty         >50K
# 1609   United-States  Local-gov    Prof-specialty        <=50K
#
# [600 rows x 10 columns]

# %% [markdown]
# ## Save Data

# %%
import os

BASE_PATH = f"./results/{DATASET.name.replace(" ", "_")}"
os.makedirs(f"{BASE_PATH}/sample", exist_ok=True)

# %%
sample.to_csv(f"{BASE_PATH}/sample/data.csv", index=False)

# %%
predict_org[org_df.columns].to_csv(f"{BASE_PATH}/predict_org.csv", index=False)
