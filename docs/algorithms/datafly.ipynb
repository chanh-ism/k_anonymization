# %% [markdown]
# # Datafly

# %%
from k_anonymization import datasets
from k_anonymization.algorithms import Datafly
# Out:
# <style>
# .dt-scroll {
#   margin: 0 0 !important;
# }
# .dtsp-panesContainer {
#   width: 100% !important;
# }
# .dt-scroll-body {
#   height: auto !important;
#   border-bottom: none !important;
# }
#
# .dt-length label {
#   padding-left: 4px;
# }
#
# div.dtsp-searchPane div.dtsp-topRow {
#   border: 0.5px solid lightgrey !important;
# }
#
# thead:has(.no-header) {
#   display: none;
# }
# </style>
# <script type="module">
#     import { set_or_remove_dark_class } from 'https://www.unpkg.com/dt_for_itables/dt_bundle.js';
#     set_or_remove_dark_class();
# </script>

# %%
datasets.MINI_CRIME
# Out:
# <style>
#         #mini_crime-buttons .dt-button-collection.dtb-collection-closeable {
#             padding: 0.5rem 0.5rem 1rem 0.5rem;
#             left: 0 !important;
#             overflow-y: auto !important;
#             max-height: -moz-available;
#             max-height: -webkit-fill-available;
#             max-height: fill-available;
#         }
#         #mini_crime-buttons div.dtsp-searchPanes {
#             width: 100% !important;
#             column-gap: 1% !important;
#             justify-content: flex-start !important;
#         }
#     </style>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_c0b28147_f5cf_4f30_86ab_4e90c87d5dc4"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
# ...

# %%
datafly = Datafly(dataset=datasets.MINI_CRIME, k=2)
datafly.anonymize()
datafly.anon_data
# Out:
# <style>
#         #anonymized_data-buttons .dt-button-collection.dtb-collection-closeable {
#             padding: 0.5rem 0.5rem 1rem 0.5rem;
#             left: 0 !important;
#             overflow-y: auto !important;
#             max-height: -moz-available;
#             max-height: -webkit-fill-available;
#             max-height: fill-available;
#         }
#         #anonymized_data-buttons div.dtsp-searchPanes {
#             width: 100% !important;
#             column-gap: 1% !important;
#             justify-content: flex-start !important;
#         }
#     </style>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_1258f0f8_9d74_4ebb_9988_e5b2f31f5f60"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
# ...
